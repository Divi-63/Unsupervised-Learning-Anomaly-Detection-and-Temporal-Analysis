# %% [markdown]
# Question 1:
# What is Dimensionality Reduction? Why is it important in machine learning?
#
# Dimensionality Reduction is the process of reducing the number of input features while keeping important information.
#
# Importance:
#
#  - Reduces computational cost
#
#  - Removes noise and redundant features
#
#  - Helps visualize high-dimensional data
#
#  - Reduces overfitting

# %% [markdown]
# Question 2:
# Name and briefly describe three common dimensionality reduction techniques.
#
#  - PCA (Principal Component Analysis) – Converts features into principal components that capture maximum variance.
#
#   - t-SNE – Non-linear technique mainly used for visualization.
#
#  - LDA (Linear Discriminant Analysis) – Supervised technique that reduces dimensions while maximizing class separation.

# %% [markdown]
# Question 3:
# What is clustering in unsupervised learning? Mention three popular clustering algorithms.
#
#  - Clustering is an unsupervised learning technique that groups similar data points without labeled data.
#
#    Popular algorithms:
#
#    K-Means
#
#    Hierarchical Clustering
#
#    DBSCAN

# %% [markdown]
# Question 4:
# Explain the concept of anomaly detection and its significance.
#
#  - Anomaly detection identifies unusual or abnormal patterns that differ from expected behavior.
#
#    Significance:
#
#      Fraud detection
#
#      Network intrusion detection
#
#      Machine failure prediction
#
#      Identifying unusual trends in data

# %% [markdown]
# Question 5 :
# List and briefly describe three types of anomaly detection techniques.
#
#  - Statistical Methods – Use distributions, probability thresholds, and statistical tests.
#
#  - Machine Learning Methods – Algorithms like Isolation Forest and One-Class SVM.
#
#  - Distance-Based Methods – Detect anomalies based on distances to neighbors (e.g., k-NN).

# %% [markdown]
# Question 6 :
# What is time series analysis? Mention two key components of time series data.
#
#  - Time series analysis studies data collected over time to identify patterns and trends.
#
#      Key components:
#
#      Trend
#
#      Seasonality

# %% [markdown]
# Question 7:
# Describe the difference between seasonality and cyclic behavior in time series.
#
#  - Seasonality: Patterns that repeat at fixed intervals (daily, monthly, yearly).
#
#  - Cyclic behavior: Patterns that occur at irregular, long-term intervals (economic cycles).

# %%
#Question 8 : Python code to perform K-means clustering on a sample dataset.
# K-Means Clustering Example

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate sample dataset
X, y = make_blobs(n_samples=300, centers=3, random_state=42)

# Perform K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

# Plot results
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            color='red', s=200, marker='X')
plt.title("K-Means Clustering Result")
plt.show()

print("Cluster Centers:\n", kmeans.cluster_centers_)
# Out:
# Cluster Centers:
#  [[-2.63323268  9.04356978]
#  [-6.88387179 -6.98398415]
#  [ 4.74710337  2.01059427]]

# %%
#Question 9: What is inheritance in OOP? Provide a simple example in Python.
# Example of Inheritance in Python

class Animal:
    def speak(self):
        return "Animal makes a sound"

class Dog(Animal):
    def speak(self):
        return "Dog barks"

d = Dog()
print(d.speak())
# Out:
# Dog barks

# %% [markdown]
# Question 10:
# How can time series analysis be used for anomaly detection?
#
#  - Time series analysis detects anomalies by identifying deviations from expected temporal patterns.
#
#  - Uses:
#
#      Detects sudden spikes or drops
#
#      Compares actual vs predicted values
#
#      Identifies deviations in trend or seasonality
#
#      Uses models like ARIMA, LSTM, Prophet
